# %%
# imports
import pandas as pd
import os 
import requests

# %%
van_stations_df = pd.read_csv("van_stations.csv")
van_stations_df.head()
# Out:
#                     name   latitude   longitude  extra.slots
# 0       Chilco & Barclay  49.291909 -123.140713           18
# 1   St George & Broadway  49.262321 -123.093060           14
# 2  Britannia Parking Lot  49.275882 -123.071865           14
# 3        Morton & Denman  49.288030 -123.142135            0
# 4    Thornton & National  49.273777 -123.092723           14

# %%
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv(dotenv_path=r'C:\Users\jessy\lighthouselabs\python\exercise\Other_data_types_exercise\.env')

FOURSQUARE_KEY = os.getenv('FOURSQUARE_API_KEY')

# %%
def get_venues_fs(latitude, longitude, radius, api_key, categories):
    """
    Get venues from foursquare with a specified place type and coordinates.
    Args:
        latitude (float): latitude for query (must be combined with longitude)
        longitude (float): longitude for query (must be combined with latitude)
        api_key (str): foursquare API to use for query
        categories (str) : Foursquare-recognized place type. If not passed no place_type will be specified. Separate ids with commas
    
    Returns:
        response: response object from the requests library.
    """

    url = "https://places-api.foursquare.com/places/search"
    headers = {
        "Accept": "application/json",
        "Authorization": api_key,
        "X-Places-Api-Version": "2025-06-17"
        }
    params = {
        "ll": f"{latitude},{longitude}",
        "radius": radius,
        "categories": categories,
        "limit": 50
        }

    response = requests.get(url, headers=headers, params=params)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"API error: {response.status_code}")
        return response.json()

# %% [markdown]
# Due to the limitation of Foursquare requesting rate, I limited the number of venues around each station to 50.

# %% [markdown]
# # Foursquare

# %% [markdown]
# Send a request to Foursquare with a small radius (1000m) for all the bike stations in your city of choice.

# %%
# Send requests to Foursquare API for all bike stations with 1000m radius

all_venues = []

print(f"Querying Foursquare API for {len(van_stations_df)} bike stations...")

for idx, station in van_stations_df.iterrows():
    station_lat = station['latitude']
    station_lon = station['longitude']
    station_name = station.get('name', f'Station_{idx}')
    
    print(f"Processing station {idx + 1}/{len(van_stations_df)}: {station_name}")
    
    try:
        venues_data = get_venues_fs(
            latitude=station_lat, 
            longitude=station_lon, 
            radius=300,  
            api_key=FOURSQUARE_KEY, 
            categories=None 
        )
        
       
        if 'results' in venues_data:
            for venue in venues_data['results']:
                venue_info = {
                    'station_name': station_name,
                    'station_latitude': station_lat,
                    'station_longitude': station_lon,
                    'station_index': idx,
                    'venue_id': venue.get('fsq_place_id', ''),
                    'venue_name': venue.get('name', ''),
                    'venue_latitude': venue.get('latitude', None),
                    'venue_longitude': venue.get('longitude', None),
                    'venue_address': venue.get('location', {}).get('address', ''),
                    'venue_categories': [cat.get('name', '') for cat in venue.get('categories', [])],
                    'distance_from_station': venue.get('distance', None)
                }
                all_venues.append(venue_info)
    
    except Exception as e:
        print(f"Error querying station {station_name}: {e}")
        continue

print(f"Completed querying all stations. Found {len(all_venues)} venues total.")
# Out:
# Querying Foursquare API for 261 bike stations...
# Processing station 1/261: Chilco & Barclay
# Processing station 2/261: St George & Broadway
# Processing station 3/261: Britannia Parking Lot
# Processing station 4/261: Morton & Denman
# Processing station 5/261: Thornton & National
# Processing station 6/261: Burrard & 14th
# Processing station 7/261: Olympic Village Station
# Processing station 8/261: 8th & Macdonald
# Processing station 9/261: 30th & Ontario
# Processing station 10/261: Lakewood & Triumph
# Processing station 11/261: 13th & Cambie
# Processing station 12/261: Arbutus & Nanton
# Processing station 13/261: 14th & Fraser
# Processing station 14/261: 15th & Victoria (Trout Lake)
# Processing station 15/261: Robson & Hornby
# Processing station 16/261: Cardero & Robson
# Processing station 17/261: 10th & Fraser
# Processing station 18/261: Ontario & 5th
# Processing station 19/261: Heather & 16th
# Processing station 20/261: Richards & Smithe
# Processing station 21/261: Robson & Beatty
# Processing station 22/261: Maple Tree Square
# Processing station 23/261: 22nd & Main
# Processing station 24/261: Carrall & Seawall
# Processing station 25/261: Charles & Woodland
# Processing station 26/261: 1st & Manitoba
# Processing station 27/261: St Catherines & 7th
# Processing station 28/261: Triumph & Victoria
# Processing station 29/261: 18th & Main
# Processing station 30/261: St Catherines & 10th
# Processing station 31/261: Nelson & Richards
# Processing station 32/261: Arbutus & 10th
# Processing station 33/261: Comox & Denman
# Processing station 34/261: Prince Edward & 14th
# Processing station 35/261: Alexander & Railway
# Processing station 36/261: Chilco & Beach
# Processing station 37/261: Richards & Cordova
# Processing station 38/261: Orchard Commons
# Processing station 39/261: Strangway Building
# Processing station 40/261: Yew & Broadway
# Processing station 41/261: Woodland & 10th
# Processing station 42/261: Ontario & 16th
# Processing station 43/261: 14th & Alder
# Processing station 44/261: Chestnut & McNicoll
# Processing station 45/261: Dunbar & 6th
# Processing station 46/261: Stanley Park - Vancouver Aquarium
# Processing station 47/261: Yaletown-Roundhouse Station
# Processing station 48/261: Smithe & Burrard
# Processing station 49/261: Abbott & Cordova
# Processing station 50/261: Sasamat & 10th
# Processing station 51/261: Vine & 4th
# Processing station 52/261: 10th & Ontario
# Processing station 53/261: Pine & 10th
# Processing station 54/261: Cordova & Granville
# Processing station 55/261: Canada Place
# Processing station 56/261: Wallace & 4th
# Processing station 57/261: Denman & Bayshore
# Processing station 58/261: Pacific & Richards
# Processing station 59/261: 7th &  Alder
# Processing station 60/261: Jervis & Robson
# Processing station 61/261: Heather & 18th
# Processing station 62/261: 14th & Oak
# Processing station 63/261: Bute & Comox
# Processing station 64/261: Comox & Broughton
# Processing station 65/261: Station & Terminal
# Processing station 66/261: Stanley Park - Third Beach Parking Lot
# Processing station 67/261: Woodland & 4th
# Processing station 68/261: 8th & Ash
# Processing station 69/261: Burrard & Drake
# Processing station 70/261: 10th & Kingsway
# Processing station 71/261: Beach & Hornby
# Processing station 72/261: Hawks & Union
# Processing station 73/261: Marinaside & Cooperage
# Processing station 74/261: Alberni & Jervis
# Processing station 75/261: 7th & Arbutus
# Processing station 76/261: 14th & Ontario
# Processing station 77/261: King Edward & Cambie
# Processing station 78/261: 1st & Fir
# Processing station 79/261: Arbutus & 16th
# Processing station 80/261: 28th & Willow
# Processing station 81/261: Arbutus Greenway & Fir
# Processing station 82/261: West Mall Swing Space Building
# Processing station 83/261: McLean & Pender
# Processing station 84/261: Bute & Barclay
# Processing station 85/261: Balsam & Cornwall
# Processing station 86/261: Hastings & Broughton
# Processing station 87/261: Seymour & Cordova
# Processing station 88/261: Alder & 11th
# Processing station 89/261: 10th & Columbia
# Processing station 90/261: Heather & 14th
# Processing station 91/261: Commercial & 20th
# Processing station 92/261: Kitsilano Beach Park
# Processing station 93/261: Rolston & Granville
# Processing station 94/261: Cordova & Bute
# Processing station 95/261: 12th & Yukon (City Hall)
# Processing station 96/261: Blenheim & 4th
# Processing station 97/261: Wylie & 2nd
# Processing station 98/261: Thurlow & Pendrell
# Processing station 99/261: 14th & Cambie
# Processing station 100/261: Granville & Georgia
# Processing station 101/261: Grant & Commercial
# Processing station 102/261: 8th & Ontario
# Processing station 103/261: Hornby & Nelson
# Processing station 104/261: šxʷƛ̓ənəq Xwtl'e7énḵ Square - Vancouver Art Gallery
# Processing station 105/261: Dunsmuir & Beatty
# Processing station 106/261: Robson & Granville
# Processing station 107/261: 4th & Commercial
# Processing station 108/261: 8th & Scotia
# Processing station 109/261: Heather & 10th
# Processing station 110/261: Homer & Robson (Vancouver Public Library)
# Processing station 111/261: 7th & Granville
# Processing station 112/261: Harwood & Bute
# Processing station 113/261: Thunderbird & Thunderbird
# Processing station 114/261: Creekside Park North
# Processing station 115/261: 10th & Commercial
# Processing station 116/261: 10th & Cambie
# Processing station 117/261: Quebec & 1st
# Processing station 118/261: Lakewood & Oxford
# Processing station 119/261: Carolina & Great Northern Way
# Processing station 120/261: Columbia & 5th
# Processing station 121/261: East Blvd & 37th
# Processing station 122/261: Trafalgar & Cornwall
# Processing station 123/261: 5th & Arbutus
# Processing station 124/261: Stanley Park - Information Booth
# Processing station 125/261: 14th & Main
# Processing station 126/261: Georgia & Main
# Processing station 127/261: Agronomy & East Mall
# Processing station 128/261: Alma & Point Grey
# Processing station 129/261: 20th & Main
# Processing station 130/261: Nelson & Mainland
# Processing station 131/261: Point Grey & Blenheim
# Processing station 132/261: Yukon & 6th
# Processing station 133/261: Burrard & 7th
# Processing station 134/261: 14th & Granville
# Processing station 135/261: Wall & Eton
# Processing station 136/261: Beach & Cardero
# Processing station 137/261: Cypress & 4th
# Processing station 138/261: Richards & Robson
# Processing station 139/261: Glen & Union
# Processing station 140/261: 8th & Yukon
# Processing station 141/261: 1st & Chestnut
# Processing station 142/261: 10th & Main
# Processing station 143/261: Georgia & Homer
# Processing station 144/261: York & Yew
# Processing station 145/261: War Memorial Gym
# Processing station 146/261: Totem Park
# Processing station 147/261: Ontario & Seawall
# Processing station 148/261: 10th & Granville
# Processing station 149/261: 15th & Knight
# Processing station 150/261: Ontario & 23rd
# Processing station 151/261: Dunbar & Broadway
# Processing station 152/261: Carrall & Hastings
# Processing station 153/261: 8th & Commercial
# Processing station 154/261: Charleson Park
# Processing station 155/261: Princess & Union
# Processing station 156/261: Stanley Park - Second Beach South
# Processing station 157/261: 6th & Carolina
# Processing station 158/261: UBC Bookstore
# Processing station 159/261: Balaclava & Broadway
# Processing station 160/261: Expo & Carrall
# Processing station 161/261: Beach & Seymour
# Processing station 162/261: 27th & Main
# Processing station 163/261: Stanley Park - Second Beach North
# Processing station 164/261: Keith & 6th
# Processing station 165/261: Jericho Beach
# Processing station 166/261: Point Grey & Bayswater
# Processing station 167/261: 7th & Woodland
# Processing station 168/261: Aquatic Centre
# Processing station 169/261: Vanier Park
# Processing station 170/261: Trafalgar & Broadway
# Processing station 171/261: Napier & Commercial
# Processing station 172/261: 7th & Laurel
# Processing station 173/261: Science World
# Processing station 174/261: Pender & Victoria
# Processing station 175/261: Cypress & 16th
# Processing station 176/261: Spyglass & Seawall
# Processing station 177/261: Keefer & Hawks
# Processing station 178/261: 29th & Cambie
# Processing station 179/261: Victoria & 10th
# Processing station 180/261: Commercial & Adanac
# Processing station 181/261: Columbia & 14th
# Processing station 182/261: Dunsmuir & Richards
# Processing station 183/261: Campbell & Hastings
# Processing station 184/261: Franklin & Nanaimo
# Processing station 185/261: Charles & Commercial
# Processing station 186/261: 1st & Scotia
# Processing station 187/261: Nelson & Denman
# Processing station 188/261: Beatty & Nelson
# Processing station 189/261: Trimble & 8th
# Processing station 190/261: David Lam Park
# Processing station 191/261: Burrard & 4th
# Processing station 192/261: Cypress & Cornwall
# Processing station 193/261: Keefer & Princess
# Processing station 194/261: qəlɬaləməcən leləm | Orca House
# Processing station 195/261: Bidwell & Burnaby
# Processing station 196/261: 11th & Kingsway
# Processing station 197/261: Pender & Burrard
# Processing station 198/261: Columbia & 1st
# Processing station 199/261: Melville & Bute
# Processing station 200/261: Anderson & 2nd
# Processing station 201/261: 5th & Main
# Processing station 202/261: Alexander & Dunlevy
# Processing station 203/261: 13th & St George
# Processing station 204/261: Commercial & Pandora
# Processing station 205/261: Quebec & 3rd
# Processing station 206/261: Grandview & Commercial
# Processing station 207/261: Expo & Smithe
# Processing station 208/261: Cypress & 14th
# Processing station 209/261: Brock Commons
# Processing station 210/261: Beach & Broughton
# Processing station 211/261: Arbutus Greenway & 14th
# Processing station 212/261: Alexander & Main
# Processing station 213/261: Hornby & Drake
# Processing station 214/261: Highbury & 8th
# Processing station 215/261: Pharmaceutical Sciences
# Processing station 216/261: Haro & Denman
# Processing station 217/261: Windsor & 14th
# Processing station 218/261: Prince Edward & 16th
# Processing station 219/261: Cardero & Davie
# Processing station 220/261: Stamps Landing
# Processing station 221/261: Marinaside & Davie
# Processing station 222/261: Adanac & McLean
# Processing station 223/261: Bute & Davie
# Processing station 224/261: Victoria & 4th
# Processing station 225/261: Heather & 29th
# Processing station 226/261: McNicoll & Arbutus
# Processing station 227/261: IK Barber Learning Centre
# Processing station 228/261: Granville Island
# Processing station 229/261: 6th & Prince Edward
# Processing station 230/261: Broughton & Davie
# Processing station 231/261: Adanac & Lakewood
# Processing station 232/261: Cypress & 10th
# Processing station 233/261: Thunderbird Parkade
# Processing station 234/261: Burrard Station (Melville & Dunsmuir)
# Processing station 235/261: 22nd & Cambie
# Processing station 236/261: Glen & Broadway
# Processing station 237/261: Nicola & Robson
# Processing station 238/261: Stanley Park - Totem Poles
# Processing station 239/261: Davie & Beach
# Processing station 240/261: Pender & Gore
# Processing station 241/261: Richards & Davie
# Processing station 242/261: Pender & Commercial
# Processing station 243/261: 18th & Cambie
# Processing station 244/261: 2nd & Commercial
# Processing station 245/261: Wesbrook Village - Berton & Shrum
# Processing station 246/261: Chilco & Robson
# Processing station 247/261: Keefer & Columbia
# Processing station 248/261: Rogers Tower
# Processing station 249/261: Woodland & Graveley
# Processing station 250/261: Cardero & Bayshore
# Processing station 251/261: 8th & Fraser
# Processing station 252/261: Spanish Banks East
# Processing station 253/261: Balaclava & 6th
# Processing station 254/261: Cambie & Water
# Processing station 255/261: Helmcken & Burrard
# Processing station 256/261: Hornby & Pender
# Processing station 257/261: 7th & Heather
# Processing station 258/261: Union & Dunlevy
# Processing station 259/261: Richards & Helmcken
# Processing station 260/261: Keefer & Abbott
# Processing station 261/261: 8th & Prince Edward
# Completed querying all stations. Found 6861 venues total.

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
# Parse through the response to get POI details (restaurants, bars, banks, landmarks, etc)
if all_venues:
    print("Parsing and analyzing Foursquare POI data...")
    
    
    temp_df = pd.DataFrame(all_venues)
    
    print("\n=== FOURSQUARE POI DATA SUMMARY ===")
    print(f"Total venues found: {len(all_venues)}")
    print(f"Total bike stations processed: {temp_df['station_index'].nunique()}")
    print(f"Average venues per station: {len(all_venues) / temp_df['station_index'].nunique():.1f}")
    
    # Analyze venue categories 
    print(f"\nVenue Categories Analysis:")
    # Flatten the venue_categories lists to count individual category types
    all_categories = []
    for categories_list in temp_df['venue_categories']:
        if isinstance(categories_list, list):
            all_categories.extend(categories_list)
    
    if all_categories:
        category_counts = pd.Series(all_categories).value_counts()
        print(f"Top 15 most common venue types:")
        for category, count in category_counts.head(15).items():
            print(f"  - {category}: {count}")
    
    # Show venues with complete address information
    venues_with_address = temp_df[temp_df['venue_address'].notna() & (temp_df['venue_address'] != '')]
    print(f"\nVenues with address information: {len(venues_with_address)}")
    
    # Distance analysis
    if temp_df['distance_from_station'].notna().any():
        print(f"\nDistance from stations (meters):")
        distance_stats = temp_df['distance_from_station'].describe()
        print(f"  - Average: {distance_stats['mean']:.1f}m")
        print(f"  - Closest: {distance_stats['min']:.1f}m") 
        print(f"  - Farthest: {distance_stats['max']:.1f}m")
    
    # Show sample venues by major categories
    print(f"\nSample venues by category:")
    
    # Look for restaurants
    restaurants = temp_df[temp_df['venue_categories'].apply(
        lambda x: any('restaurant' in cat.lower() or 'food' in cat.lower() or 'cafe' in cat.lower() 
                     for cat in x) if isinstance(x, list) else False)]
    print(f"  - Restaurants/Food: {len(restaurants)} venues")
    if len(restaurants) > 0:
        print(f"    Sample: {restaurants['venue_name'].head(3).tolist()}")
    
    # Look for banks
    banks = temp_df[temp_df['venue_categories'].apply(
        lambda x: any('bank' in cat.lower() or 'atm' in cat.lower() 
                     for cat in x) if isinstance(x, list) else False)]
    print(f"  - Banks/Financial: {len(banks)} venues")
    if len(banks) > 0:
        print(f"    Sample: {banks['venue_name'].head(3).tolist()}")
    
    # Look for landmarks/attractions
    landmarks = temp_df[temp_df['venue_categories'].apply(
        lambda x: any('landmark' in cat.lower() or 'tourist' in cat.lower() or 'monument' in cat.lower() 
                     for cat in x) if isinstance(x, list) else False)]
    print(f"  - Landmarks/Tourist Attractions: {len(landmarks)} venues")
    if len(landmarks) > 0:
        print(f"    Sample: {landmarks['venue_name'].head(3).tolist()}")
    
    # Look for retail/shopping
    retail = temp_df[temp_df['venue_categories'].apply(
        lambda x: any('shop' in cat.lower() or 'store' in cat.lower() or 'retail' in cat.lower() 
                     for cat in x) if isinstance(x, list) else False)]
    print(f"  - Retail/Shopping: {len(retail)} venues")
    if len(retail) > 0:
        print(f"    Sample: {retail['venue_name'].head(3).tolist()}")
        
else:
    print("No venues found. Please check API key and network connection.")
# Out:
# Parsing and analyzing Foursquare POI data...
#
# === FOURSQUARE POI DATA SUMMARY ===
# Total venues found: 6861
# Total bike stations processed: 261
# Average venues per station: 26.3
#
# Venue Categories Analysis:
# Top 15 most common venue types:
#   - Coffee Shop: 624
#   - Café: 437
#   - Sushi Restaurant: 264
#   - Japanese Restaurant: 243
#   - Bakery: 221
#   - Pizzeria: 181
#   - Restaurant: 174
#   - Fast Food Restaurant: 164
#   - Sandwich Spot: 152
#   - Dessert Shop: 150
#   - Grocery Store: 149
#   - Park: 146
#   - Pub: 134
#   - Bar: 131
#   - Chinese Restaurant: 130
#
# Venues with address information: 6384
#
# Distance from stations (meters):
#   - Average: 174.1m
#   - Closest: 3.0m
#   - Farthest: 307.0m
#
# Sample venues by category:
#   - Restaurants/Food: 2278 venues
#     Sample: ['Carp', 'Subway', 'Thai Son']
#   - Banks/Financial: 0 venues
#   - Landmarks/Tourist Attractions: 23 venues
#     Sample: ['Terry Fox Plaza', 'Roger Neilson Statue', 'Gastown Steam Clock']
#   - Retail/Shopping: 2074 venues
#     Sample: ['Blenz Coffee', "Kim's Mart", 'Paper Crane Coffee Company']

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
# Create the final Foursquare DataFrame
foursquare_df = pd.DataFrame(all_venues)


if not foursquare_df.empty:
    foursquare_df['venue_categories_str'] = foursquare_df['venue_categories'].apply(
        lambda x: ', '.join(x) if isinstance(x, list) else str(x)
    )
    
   
    column_order = [
        'station_name', 'station_index', 'station_latitude', 'station_longitude',
        'venue_name', 'venue_id', 'venue_categories_str',
        'venue_latitude', 'venue_longitude', 'venue_address', 
        'distance_from_station'
    ]
    
    
    available_columns = [col for col in column_order if col in foursquare_df.columns]
    foursquare_df = foursquare_df[available_columns]
    
    print(f"Foursquare DataFrame created successfully!")
    print(f"Shape: {foursquare_df.shape}")
    print(f"Columns: {list(foursquare_df.columns)}")
    
    
    print("\nFirst 5 rows of Foursquare data:")
    display(foursquare_df.head())
    
    
    print(f"\nDataFrame Info:")
    print(f"- Total venues: {len(foursquare_df)}")
    print(f"- Venues per station (average): {len(foursquare_df) / len(van_stations_df):.1f}")
    print(f"- Unique venue categories: {foursquare_df['venue_categories_str'].nunique()}")
    
    # Save the DataFrame to CSV for future use
    output_file = "foursquare_venues.csv"
    foursquare_df.to_csv(output_file, index=False)
    print(f"✅ Foursquare data saved to '{output_file}'")
    
else:
    print("No data available to create DataFrame.")
    foursquare_df = pd.DataFrame()
# Out:
# Foursquare DataFrame created successfully!
# Shape: (6861, 11)
# Columns: ['station_name', 'station_index', 'station_latitude', 'station_longitude', 'venue_name', 'venue_id', 'venue_categories_str', 'venue_latitude', 'venue_longitude', 'venue_address', 'distance_from_station']
#
# First 5 rows of Foursquare data:
#        station_name  station_index  station_latitude  station_longitude  \
# 0  Chilco & Barclay              0         49.291909        -123.140713
# 1  Chilco & Barclay              0         49.291909        -123.140713
# 2  Chilco & Barclay              0         49.291909        -123.140713
# 3  Chilco & Barclay              0         49.291909        -123.140713
# 4  Chilco & Barclay              0         49.291909        -123.140713
#
#                                venue_name                  venue_id  \
# 0                            Blenz Coffee  4aa97278f964a520b25320e3
# 1                             Haro Street  4d5474a0cc65a1434d2f425e
# 2                        RSVP Finish Line  520ff63111d2fbdd436c4aaf
# 3  Ted and Mary Greig Rhododendron Garden  4bd4c2b3637ba593fd68f570
# 4                             Jungle Room  6455be524d616826ab184696
#
#   venue_categories_str  venue_latitude  venue_longitude     venue_address  \
# 0          Coffee Shop       49.290251      -123.137470     935 Denman St
# 1         Neighborhood       49.291210      -123.137897
# 2                Plaza       49.289984      -123.141443
# 3               Garden       49.293592      -123.142806      Stanley Park
# 4                  Bar       49.289990      -123.138117  961 Denman St. P
#
#    distance_from_station
# 0                    298
# 1                    218
# 2                    220
# 3                    240
# 4                    284
# DataFrame Info:
# - Total venues: 6861
# - Venues per station (average): 26.3
# - Unique venue categories: 867
# ✅ Foursquare data saved to 'foursquare_venues.csv'

# %% [markdown]
# #### Since I am not able to access Yelp, so I did some additional analysis of the Foursquare data:
# 1. top 10 most common venues
# 2. distance analysis
# 3. top 10 most common venue category
# 4. data quality check
# 5. geography distribution
# 6. analyze the number of venues

# %%
# # Additional detailed analysis of the Foursquare data
print("=== DETAILED FOURSQUARE ANALYSIS ===\n")

if not foursquare_df.empty:
    print("1. Top 10 Most Common Venue Names:")
    venue_name_counts = foursquare_df['venue_name'].value_counts().head(10)
    print(venue_name_counts)
    
    print("\n2. Venues by Distance from Station:")
    if foursquare_df['distance_from_station'].notna().any():
        distance_stats = foursquare_df['distance_from_station'].describe()
        print(distance_stats)
    else:
        print("No distance data available")
    
    print("\n3. Top 10 Most Common Venue Category Combinations:")
    unique_categories = foursquare_df['venue_categories_str'].value_counts().head(10)
    print(unique_categories)
    
        
    print("\n4. Data Quality Check:")
    print(f"- Missing venue names: {foursquare_df['venue_name'].isna().sum()}")
    print(f"- Missing coordinates: {foursquare_df[['venue_latitude', 'venue_longitude']].isna().sum().sum()}")
    print(f"- Missing addresses: {foursquare_df['venue_address'].isna().sum()}")
    print(f"- Venues with complete data: {len(foursquare_df.dropna())}")
    
    print("\n5. Geographic Distribution:")
    print(f"- Latitude range: {foursquare_df['venue_latitude'].min():.6f} to {foursquare_df['venue_latitude'].max():.6f}")
    print(f"- Longitude range: {foursquare_df['venue_longitude'].min():.6f} to {foursquare_df['venue_longitude'].max():.6f}")

    print("\n6. Venue Count Analysis by Station:")
    # Count venues per station
    venues_per_station = foursquare_df.groupby('station_name').size()
    
    print(f"- Total number of stations: {len(venues_per_station)}")
    print(f"- Average venues per station: {venues_per_station.mean():.2f}")
    print(f"- Minimum venues per station: {venues_per_station.min()}")
    print(f"- Maximum venues per station: {venues_per_station.max()}")
    print(f"- Median venues per station: {venues_per_station.median():.2f}")
    print(f"- Standard deviation: {venues_per_station.std():.2f}")
    
    # Show stations with highest and lowest venue counts
    print(f"\nTop 5 stations with most venues:")
    top_stations = venues_per_station.nlargest(5)
    for station, count in top_stations.items():
        print(f"  - {station}: {count} venues")
    
    print(f"\nBottom 5 stations with fewest venues:")
    bottom_stations = venues_per_station.nsmallest(5)
    for station, count in bottom_stations.items():
        print(f"  - {station}: {count} venues")
    
    # Distribution analysis
    print(f"\nVenue count distribution:")
    venue_dist = venues_per_station.value_counts().sort_index()
    for count, stations in venue_dist.items():
        print(f"  - {stations} station(s) have {count} venue(s)")
    
    print(f"\n✅ Analysis complete! Total of {len(foursquare_df)} venues analyzed across {len(venues_per_station)} stations.")
    
else:
    print("No Foursquare data available for detailed analysis.")
# Out:
# === DETAILED FOURSQUARE ANALYSIS ===
#
# 1. Top 10 Most Common Venue Names:
# venue_name
# Starbucks             127
# Subway                 61
# Tim Hortons            43
# Blenz Coffee           42
# JJ Bean                37
# Shoppers Drug Mart     33
# BC Liquor Store        32
# A&W Restaurant         21
# Cactus Club Cafe       20
# London Drugs           20
# Name: count, dtype: int64
#
# 2. Venues by Distance from Station:
# count    6861.000000
# mean      174.050721
# std        74.703962
# min         3.000000
# 25%       115.000000
# 50%       179.000000
# 75%       237.000000
# max       307.000000
# Name: distance_from_station, dtype: float64
#
# 3. Top 10 Most Common Venue Category Combinations:
# venue_categories_str
# Coffee Shop              426
# Sushi Restaurant         178
# Pizzeria                 138
# Japanese Restaurant      128
# Café                     126
# Restaurant               101
# Park                      97
# Vietnamese Restaurant     97
# Bakery                    93
# Chinese Restaurant        83
# Name: count, dtype: int64
#
# 4. Data Quality Check:
# - Missing venue names: 0
# - Missing coordinates: 0
# - Missing addresses: 477
# - Venues with complete data: 6336
#
# 5. Geographic Distribution:
# - Latitude range: 49.236338 to 49.303382
# - Longitude range: -123.256381 to -123.053458
#
# 6. Venue Count Analysis by Station:
# - Total number of stations: 261
# - Average venues per station: 26.29
# - Minimum venues per station: 1
# - Maximum venues per station: 50
# - Median venues per station: 24.00
# - Standard deviation: 17.10
#
# Top 5 stations with most venues:
#   - 10th & Cambie: 50 venues
#   - 10th & Kingsway: 50 venues
#   - 10th & Main: 50 venues
#   - 14th & Main: 50 venues
#   - 22nd & Main: 50 venues
#
# Bottom 5 stations with fewest venues:
#   - Columbia & 14th: 1 venues
#   - Cypress & 14th: 1 venues
#   - Cypress & 16th: 1 venues
#   - Point Grey & Blenheim: 1 venues
#   - 14th & Alder: 2 venues
#
# Venue count distribution:
#   - 4 station(s) have 1 venue(s)
#   - 5 station(s) have 2 venue(s)
#   - 8 station(s) have 3 venue(s)
#   - 4 station(s) have 4 venue(s)
#   - 6 station(s) have 5 venue(s)
#   - 4 station(s) have 6 venue(s)
#   - 8 station(s) have 7 venue(s)
#   - 7 station(s) have 8 venue(s)
#   - 12 station(s) have 9 venue(s)
#   - 6 station(s) have 10 venue(s)
#   - 9 station(s) have 11 venue(s)
#   - 7 station(s) have 12 venue(s)
#   - 6 station(s) have 13 venue(s)
#   - 8 station(s) have 14 venue(s)
#   - 9 station(s) have 15 venue(s)
#   - 3 station(s) have 16 venue(s)
#   - 3 station(s) have 17 venue(s)
#   - 3 station(s) have 19 venue(s)
#   - 4 station(s) have 20 venue(s)
#   - 3 station(s) have 21 venue(s)
#   - 8 station(s) have 22 venue(s)
#   - 1 station(s) have 23 venue(s)
#   - 8 station(s) have 24 venue(s)
#   - 1 station(s) have 25 venue(s)
#   - 3 station(s) have 26 venue(s)
#   - 2 station(s) have 27 venue(s)
#   - 4 station(s) have 28 venue(s)
#   - 7 station(s) have 29 venue(s)
#   - 3 station(s) have 30 venue(s)
#   - 3 station(s) have 31 venue(s)
#   - 4 station(s) have 32 venue(s)
#   - 7 station(s) have 33 venue(s)
#   - 1 station(s) have 34 venue(s)
#   - 3 station(s) have 35 venue(s)
#   - 3 station(s) have 36 venue(s)
#   - 1 station(s) have 37 venue(s)
#   - 2 station(s) have 38 venue(s)
#   - 3 station(s) have 39 venue(s)
#   - 1 station(s) have 40 venue(s)
#   - 1 station(s) have 41 venue(s)
#   - 2 station(s) have 42 venue(s)
#   - 7 station(s) have 43 venue(s)
#   - 2 station(s) have 44 venue(s)
#   - 2 station(s) have 46 venue(s)
#   - 3 station(s) have 47 venue(s)
#   - 1 station(s) have 48 venue(s)
#   - 1 station(s) have 49 venue(s)
#   - 58 station(s) have 50 venue(s)
#
# ✅ Analysis complete! Total of 6861 venues analyzed across 261 stations.

# %% [markdown]
# # Yelp

# %% [markdown]
# Send a request to Yelp with a small radius (1000m) for all the bike stations in your city of choice.

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %% [markdown]
# Put your parsed results into a DataFrame

# %% [markdown]
# # Comparing Results

# %% [markdown]
# Which API provided you with more complete data? Provide an explanation.

# %% [markdown]
# Get the top 10 restaurants according to their rating
